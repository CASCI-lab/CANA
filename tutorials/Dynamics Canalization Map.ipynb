# %% [markdown]
# # Tutorial - Dynamics Canalization Map (DCM)

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys
import os

sys.path.insert(0, os.path.abspath(r'C:\Users\Srikanth\OneDrive\Documents\GitHub\CANA_CLONE\CANA\cana'))

# %%
import os
import sys
sys.path.insert(0, os.path.abspath('..'))
from cana.datasets.bio import THALIANA
from cana.drawing.canalizing_map import draw_canalizing_map_graphviz
from IPython.display import display
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 4
#       2 import sys
#       3 sys.path.insert(0, os.path.abspath('..'))
# ----> 4 from cana.datasets.bio import THALIANA
#       5 from cana.drawing.canalizing_map import draw_canalizing_map_graphviz
#       6 from IPython.display import display
#
# File c:\Users\Srikanth\OneDrive\Documents\GitHub\CANA_CLONE\CANA\cana\datasets\bio.py:19
#      10 #   Copyright (C) 2021 by
#      11 #   Alex Gates <ajgates42@gmail.com>
#      12 #   Rion Brattig Correia <rionbr@gmail.com>
#    (...)
#      15 #   All rights reserved.
#      16 #   MIT license.
#      17 import os
# ---> 19 from ..boolean_network import BooleanNetwork
#      21 _path = os.path.dirname(os.path.realpath(__file__))
#      22 """ Make sure we know what the current directory is """
#
# File c:\Users\Srikanth\OneDrive\Documents\GitHub\CANA_CLONE\CANA\cana\boolean_network.py:32
#      29 import networkx as nx
#      30 import numpy as np
# ---> 32 import cana.bns as bns
#      33 from cana.boolean_node import BooleanNode
#      34 from cana.control import fvs, mds, sc
#
# File c:\Users\Srikanth\OneDrive\Documents\GitHub\CANA_CLONE\CANA\cana\bns\__init__.py:32
#      29 import subprocess
#      30 import tempfile
# ---> 32 from cana.utils import binstate_to_statenum
#      34 _path = os.path.dirname(os.path.realpath(__file__))
#      35 """ Make sure we know what the current directory is """
#
# File c:\Users\Srikanth\OneDrive\Documents\GitHub\CANA_CLONE\CANA\cana\utils.py:10
#       7 import networkx as nx
#       8 import numpy as np
# ---> 10 from cana.cutils import binstate_to_statenum, flip_binstate_bit, statenum_to_binstate
#      13 def flip_bitset_in_strstates(strstates, idxs):
#      14     """Flips the binary value for a set of bits in a binary state.
#      15
#      16     Args:
#    (...)
#      25         ['100','001']
#      26     """
#
# ModuleNotFoundError: No module named 'cana.cutils'

# %%
N = THALIANA()

# %%
# Request the CM for one node (note that the node doesn't know the name of its inputs)
CM = N.nodes[2].canalizing_map()
# Draw using the graphviz interface.
gCM = draw_canalizing_map_graphviz(CM)
# Display
display(gCM)

# %%
# Request the DCM to the Network
DCM = N.dynamics_canalization_map(simplify=True)
# Draws using the graphviz interface.
gDCM = draw_canalizing_map_graphviz(DCM)
# Display
display(gDCM)
# Out:
# Warning: node 'var-5-out-0', graph '%3' size too small for label
# Warning: node 'var-5-out-1', graph '%3' size too small for label
